# %%
import pandas as pd
import numpy as np
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import chi2_contingency

# %%
url = 'https://drive.google.com/file/d/1Mr0iYPnyyOlXWntN0VcfAFu8aOdbSB_c/view?usp=sharing'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
eniac_a = pd.read_csv(path)

eniac_a
# Out:
#     Element ID Tag name                  Name  No. clicks  Visible?  \
# 0           48       h1                 ENIAC         269      True
# 1           25      div             mySidebar         309      True
# 2            4        a                   Mac         279      True
# 3           69        a                iPhone         246      True
# 4          105        a           Accessories        1235      True
# 5           36        a     Chargers & Cables        1261     False
# 6           99        a    iPhone Accessories        1226     False
# 7           68        a     Watch Accessories        1261     False
# 8           13        a       Mac Accessories        1308     False
# 9           15        a                AirTag         206     False
# 10           9        a                  iPad         186      True
# 11          52        a                 Watch         212      True
# 12          33        a               Storage         198      True
# ...

# %%
url = 'https://drive.google.com/file/d/1iqqcAy0rx_z4z2W34-Pt7WxbTmVNtGsc/view?usp=sharing'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
eniac_b = pd.read_csv(path)

eniac_b
# Out:
#     Element ID Tag name                  Name  No. clicks  Visible?  \
# 0           48       h1                 ENIAC         236      True
# 1           25      div             mySidebar         304      True
# 2            4        a                   Mac         268      True
# 3           69        a                iPhone         260      True
# 4          105        a           Accessories        1214      True
# 5           36        a     Chargers & Cables        1259     False
# 6           99        a    iPhone Accessories        1237     False
# 7           68        a     Watch Accessories        1221     False
# 8           13        a       Mac Accessories        1210     False
# 9           15        a                AirTag         195     False
# 10           9        a                  iPad         219      True
# 11          52        a                 Watch         209      True
# 12          33        a               Storage         203      True
# ...

# %%
url = 'https://drive.google.com/file/d/1Ff0T1lha1WCRnBfiD7Hq142ACiZ8uatZ/view?usp=sharing'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
eniac_c = pd.read_csv(path)

eniac_c
# Out:
#     Element ID Tag name                  Name  No. clicks  Visible?  \
# 0           48       h1                 ENIAC         288      True
# 1           25      div             mySidebar         283      True
# 2            4        a                   Mac         262      True
# 3           69        a                iPhone         234      True
# 4          105        a           Accessories        1288      True
# 5           36        a     Chargers & Cables        1224     False
# 6           99        a    iPhone Accessories        1175     False
# 7           68        a     Watch Accessories        1264     False
# 8           13        a       Mac Accessories        1203     False
# 9           15        a                AirTag         202     False
# 10           9        a                  iPad         228      True
# 11          52        a                 Watch         203      True
# 12          33        a               Storage         173      True
# ...

# %%
url = 'https://drive.google.com/file/d/1WamSFZac2AQVgAfkY6h4xBH7Wxs7y-cs/view?usp=sharing'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
eniac_d = pd.read_csv(path)

eniac_d
# Out:
#     Element ID Tag name                  Name  No. clicks  Visible?  \
# 0           48       h1                 ENIAC         285      True
# 1           25      div             mySidebar         305      True
# 2            4        a                   Mac         274      True
# 3           69        a                iPhone         243      True
# 4          105        a           Accessories        1267      True
# 5           36        a     Chargers & Cables        1260     False
# 6           99        a    iPhone Accessories        1296     False
# 7           68        a     Watch Accessories        1252     False
# 8           13        a       Mac Accessories        1273     False
# 9           15        a                AirTag         201     False
# 10           9        a                  iPad         200      True
# 11          52        a                 Watch         195      True
# 12          33        a               Storage         205      True
# ...

# %% [markdown]
# # Hypothesis testing: Chi-Square Test within the Eniac case study
#
# In this notebook we perform a chi-square test with the data from the Eniac case study, applying a post-hoc correction to perform pairwise tests and find the true winner.

# %% [markdown]
# ## 1.&nbsp;State the Null Hypothesis and the Alternative Hypothesis.

# %% [markdown]
# Null Hypothesis: The 4 versions of the button are equally likely to receive clicks, and the observed differences are due to chance.
#
# Alternative Hypothesis: The observed differences are not due to chance: there is at least one version that got so many more/much less clicks than the others that this can hardly be explained just by chance (i.e. they have a better/worse CTR, a better/worse performance).

# %% [markdown]
# ## 2.&nbsp; Select an appropriate significance level alpha ($\alpha$).
#
# It was decided that a relatively high alpha was acceptable in this case

# %%
alpha = 0.05

# %% [markdown]
# ## 3.&nbsp; Collect data that is random and independent
#
# The important pieces of information (clicks on each element of interest & visits on each page) are scattered around. Let's collect them. Where are the .csv files? 🥸

# %%
Click = [eniac_a.iloc[21,3], eniac_b.iloc[21,3], eniac_c.iloc[21,3], eniac_d.iloc[21,3]]
Click
# Out:
# [np.int64(512), np.int64(281), np.int64(527), np.int64(193)]

# %%
Click = [eniac_a.iloc[21,3], eniac_b.iloc[21,3], eniac_c.iloc[21,3], eniac_d.iloc[21,3]]
No_click = [(25326-eniac_a.iloc[21,3]), (24747-eniac_b.iloc[21,3]), (24876-eniac_c.iloc[21,3]), (25233-eniac_d.iloc[21,3])]

observed_results = pd.DataFrame(
    [Click, No_click], columns=["A", "B", "C", "D"], index=["Click", "No-click"]
)
observed_results
# Out:
#               A      B      C      D
# Click       512    281    527    193
# No-click  24814  24466  24349  25040

# %% [markdown]
# ## 4.&nbsp; Calculate the test result

# %%
chisq, pvalue, df, expected = chi2_contingency(observed_results)

# %%
chisq
# Out:
# np.float64(224.01877488058412)

# %%
pvalue
# Out:
# np.float64(2.7161216607868712e-48)

# %%
df
# Out:
# 3

# %%
expected
# Out:
# array([[  382.48625502,   373.74189974,   375.69012397,   381.08172127],
#        [24943.51374498, 24373.25810026, 24500.30987603, 24851.91827873]])

# %%
# Calculate row totals - stored as a vertical DataFrame
row_totals = observed_results.sum(axis=1).to_frame()

# Calculate column totals - stored as a horizontal DataFrame
column_totals = observed_results.sum(axis=0).to_frame().T

# Calculate the grand total - a single value
grand_total = observed_results.values.sum()

# Calculate the population proportions
proportions = column_totals/grand_total

# Multiply proportions by row totals to get expected values
expected_results = row_totals.dot(proportions)

expected_results
# Out:
#                      A           B             C             D
# Click       382.486255    373.7419    375.690124    381.081721
# No-click  24943.513745  24373.2581  24500.309876  24851.918279

# %%
chi_squared = (
    ((observed_results - expected_results) ** 2 / expected_results)
    .sum() # add up the columns
    .sum() # add column sums together
)
chi_squared
# Out:
# np.float64(224.01877488058415)

# %% [markdown]
# ## 5.&nbsp; Interpret the test result

# %%
if pvalue > alpha:
    print("The p-value is larger than alpha.")
else:
    print("The p-value is smaller than alpha.")
# Out:
# The p-value is smaller than alpha.

# %% [markdown]
# We reject the null hypothesis because the p-value is smaller than alpha.

# %% [markdown]
# ## How do we decide who's the winner?

# %% [markdown]
# A-B version

# %%
Click = [eniac_a.iloc[21,3], eniac_b.iloc[21,3]]
No_click = [(25326-eniac_a.iloc[21,3]), (25326-eniac_b.iloc[21,3])]

observed_results_ab = pd.DataFrame(
    [Click, No_click], columns=["A", "B"], index=["Click", "No-click"]
)
observed_results_ab
# Out:
#               A      B
# Click       512    281
# No-click  24814  25045

# %%
alpha2=0.0083 #The first alpha (above) is divided by the number of pairs where we will apply it.

# %%
# Calculate row totals - stored as a vertical DataFrame
row_totals = observed_results_ab.sum(axis=1).to_frame()

# Calculate column totals - stored as a horizontal DataFrame
column_totals = observed_results_ab.sum(axis=0).to_frame().T

# Calculate the grand total - a single value
grand_total = observed_results_ab.values.sum()

# Calculate the population proportions
proportions = column_totals/grand_total

# Multiply proportions by row totals to get expected values
expected_results2 = row_totals.dot(proportions)

expected_results2
# Out:
#                 A        B
# Click       396.5    396.5
# No-click  24929.5  24929.5

# %%
chisq, pvalue, df, expected = chi2_contingency(observed_results_ab)

# %%
chi_squared2 = (
    ((observed_results_ab - expected_results2) ** 2 / expected_results2)
    .sum() # add up the columns
    .sum() # add column sums together
)
chi_squared2
# Out:
# np.float64(68.36027590238268)

# %%
if pvalue > alpha2:
    print("The p-value is larger than alpha.")
else:
    print("The p-value is smaller than alpha.")
# Out:
# The p-value is smaller than alpha.

# %%
columns = observed_results.columns

for i in range(len(cols)):
    for x in range(i + 1, len(cols)):
        col1, col2 = cols[i], cols[x]
        table = observed_results[[col1, col2]]
        chi2, p, dof, expected = chi2_contingency(table)

        print(f"Comparison: {col1} vs {col2}")
        print(table)
        print(f"Chi-square = {round((chi2), 12)}, p-value = {round((p), 12)}")
        if p > alpha2:
          print("The p-value is larger than alpha.")
        else:
          print("The p-value is smaller than alpha.")
# Out:
# Comparison: A vs B
#               A      B
# Click       512    281
# No-click  24814  24466
# Chi-square = 62.493622855508, p-value = 0.0
# The p-value is smaller than alpha.
# Comparison: A vs C
#               A      C
# Click       512    527
# No-click  24814  24349
# Chi-square = 0.534210294332, p-value = 0.464842123017
# The p-value is larger than alpha.
# Comparison: A vs D
#               A      D
# Click       512    193
# No-click  24814  25040
# Chi-square = 144.28318375013, p-value = 0.0
# The p-value is smaller than alpha.
# Comparison: B vs C
#               B      C
# Click       281    527
# No-click  24466  24349
# Chi-square = 74.229172419456, p-value = 0.0
# The p-value is smaller than alpha.
# Comparison: B vs D
#               B      D
# Click       281    193
# No-click  24466  25040
# Chi-square = 17.876339585535, p-value = 2.3573374e-05
# The p-value is smaller than alpha.
# Comparison: C vs D
#               C      D
# Click       527    193
# ...

# %% [markdown]
# Rates

# %%
#Click-through rates by versions (total visits divided by clicks)
Rates = [eniac_a.iloc[21,3]/(25326), (eniac_b.iloc[21,3]/24747), (eniac_c.iloc[21,3]/24876), (eniac_d.iloc[21,3]/25233)]

rates = pd.DataFrame(
    [Rates], columns=["A", "B", "C", "D"], index=["Rates"]
)
rates
# Out:
#               A         B         C         D
# Rates  0.020216  0.011355  0.021185  0.007649

# %%
#rates.plot.bar(color="lightseagreen");


cols = rates.columns
values = rates.loc["Rates"]

plt.figure(figsize=(6,4))
plt.bar(cols, values)

plt.title("Click-through rates by versions")
plt.ylabel("Rate")
plt.xlabel("Versions")
# Out:
# Text(0.5, 0, 'Versions')

# %%
observed_results_2 = observed_results.loc["Click"]
expected_results_2 = expected_results.loc["Click"]

click_proportions = [(round(observed_results_2["A"]/expected_results_2["A"]*100, 2)), (round(observed_results_2["B"]/expected_results_2["B"]*100, 2)), (round(observed_results_2["C"]/expected_results_2["C"]*100, 2)), (round(observed_results_2["D"]/expected_results_2["D"]*100, 2))]
observed_expected = pd.DataFrame(
    [click_proportions], columns=["A", "B", "C", "D"], index=["Click proportions (expected/observed)"]
)
observed_expected
# Out:
#                                             A      B       C      D
# Click proportions (expected/observed)  133.86  75.19  140.28  50.65

# %%
cols2 = observed_expected.columns
values2 = observed_expected.loc["Click proportions (expected/observed)"]

plt.figure(figsize=(6,4))
plt.bar(cols2, values2)

plt.title("Click proportions (expected/observed)")
plt.ylabel("Rate (%)")
plt.xlabel("Versions")
# Out:
# Text(0.5, 0, 'Versions')

# %% [markdown]
# Version C is the winner, although the difference is not big between the original version (A) with 133.86% and version C with 140% compared to the expected results. If the company has resources to try out a new version, I would recommend to choose version C, but if they do not have resources for this, they can proceed with the original version (A).
